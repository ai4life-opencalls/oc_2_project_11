# %%
from pathlib import Path

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch

# from segment_anything import build_sam_vit_h
from segment_anything import sam_model_registry, SamPredictor
from PIL import Image

from utils import (
    get_point_coord,
    get_polygon,
    show_points,
    show_res_multi,
    show_res,
    plot_mask_and_label
)

# %%
def get_image(image_name, input_dir):
    # some image files have <space> in their names,
    # but <space> replaced by <_> in the csv table.
    image_file = input_dir.joinpath(image_name)
    if not image_file.exists():
        # try to find the image
        image_file = None
        for file in input_dir.glob("*.jpg"):
            if image_name.replace("_", " ") == file.name.replace("_", " "):
                image_file = input_dir.joinpath(file.name)
                break

    if image_file is not None:
        test_image = Image.open(image_file)
        return np.array(test_image)
    else:
        return None

def save_image_masks(masks, image_name, results_dir):
    save_dir = results_dir.joinpath(image_name)
    save_dir.mkdir(parents=True, exist_ok=True)
    for i, mask in enumerate(masks):
        # mask is 3D: 1, y, x
        mask_img = mask[0].astype(np.uint8) * 255
        mask_img = Image.fromarray(mask_img)
        mask_img.save(save_dir.joinpath(f"{i:03d}.png"))

# %%
# Input and output directory, suffix of the input files to process:

input_dir = Path("../../data/20240813_data/VID_05_GP_50/")
#input_dir = Path("../../data/training_data/")

print(input_dir.exists())

image_suffix = ".jpg"  # Change this to match your image suffix
annotation_suffix = ".txt"  # Change this to match your annotation suffix
annotation_folder = "Annotations"

output_dir = Path("../../data/20240813_data_output/VID_05_GP_50/")
#output_dir = Path("../../data/training_data_output/")



#annotation_file = Path(
#    "../../data/training_data/1/Annotations/14717-training-images-1.csv"
#)
#print(annotation_file.exists())

# %% [markdown]
# Download the large SAM model's weights from here:
# https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth
#
# For all available models see here: https://github.com/facebookresearch/segment-anything?tab=readme-ov-file#model-checkpoints

# %%
sam_checkpoint = "../../SAM_models/sam_vit_h_4b8939.pth"
model_type = "vit_h"

sam = sam_model_registry[model_type](checkpoint=sam_checkpoint)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
sam.to(device=device)

predictor = SamPredictor(sam)

# %%
# Slow version - next window tries to make it faster
def process_file(dir_path, filename):
    
    in_file = os.path.join(input_dir, dir_path, filename)
    out_folder = os.path.join(output_dir, dir_path)

    # Take the name of the image without the suffix 
    basename = os.path.basename(in_file).split(image_suffix)[0]
    annotation_file = os.path.join(input_dir, dir_path, annotation_folder, basename + "_3840x2160" + annotation_suffix) # 3840x2160, 2704x1520
    #annotation_file = os.path.join(input_dir, dir_path, annotation_folder, "14717-training-images-1"+ annotation_suffix)
    print(annotation_file)
    print(in_file)
    print(in_file)

    # If output folder does not exist, create one
    os.makedirs(out_folder, exist_ok=True)
 
    # load the annotation file related to the image
    df_annotations = pd.read_csv(annotation_file, delimiter="\t", header=None, names=["x", "y", "label_name"])
    #df_annotations = pd.read_csv(annotation_file)
    print(df_annotations)
    df_points = df_annotations
    #df_points = df_annotations[df_annotations["shape_name"] == "Point"]

    # load the image 
    test_image = np.array(Image.open(in_file))
    #test_image = get_image(image_name, input_dir)
         
    for row in np.arange(0, len(df_annotations), 1):
        print(f"\nRow: {row}")
        print(row)
        out_file = os.path.join(output_dir, dir_path, basename + "_" +str(row) + image_suffix)
        #print(f"\nProcessing {image_name}")

        # get point coordinates; df_annotations.loc[row, "x"]; float(y), float(x)
        point_prompts = [[float(df_annotations.loc[row, "x"]),float(df_annotations.loc[row, "y"])]] #2704 - x
            #df_points.loc[row]["points"].apply(get_point_coord).to_list())
        print(point_prompts)
        point_prompts = np.array(point_prompts, dtype=np.float32)
        prompt_labels = np.ones(len(point_prompts))  # positive prompt
        print(point_prompts)
        print(prompt_labels)

        # get label names
        species = (df_points.loc[row]["label_name"])
        print(species)
        
        # plot image + points
        #fig, ax = plt.subplots(1, 1, figsize=(10, 10))
        #ax.imshow(test_image)
        #show_points(point_prompts, prompt_labels, ax, marker_size=20)
        #plt.show()

        # get the SAM predictions for each point
        print(f"getting predictions for {len(point_prompts)} point prompts...")
        predictor.set_image(test_image)
        mask, score, logits = predictor.predict(
                point_coords=point_prompts,
                point_labels=prompt_labels,
                multimask_output=False,
        )
        plot_mask_and_label(mask, species, out_file, input_point=point_prompts, input_label=prompt_labels, image=test_image, saveit = True)

# %%
# Aims to be a faster version of the code up
def process_file(dir_path, filename):
    
    in_file = os.path.join(input_dir, dir_path, filename)
    out_folder = os.path.join(output_dir, dir_path)

    # Take the name of the image without the suffix 
    basename = os.path.basename(in_file).split(image_suffix)[0]
    annotation_file = os.path.join(input_dir, dir_path, annotation_folder, basename + "_3840x2160" + annotation_suffix)
    #annotation_file = os.path.join(input_dir, dir_path, annotation_folder, "14717-training-images-1"+ annotation_suffix)
    print(annotation_file)
    print(in_file)

    # If output folder does not exist, create one
    os.makedirs(out_folder, exist_ok=True)
 
    # load the annotation file related to the image
    df_annotations = pd.read_csv(annotation_file, delimiter="\t", header=None, names=["x", "y", "label_name"])
    #df_annotations = pd.read_csv(annotation_file)
    print(df_annotations)
    df_points = df_annotations
    #df_points = df_annotations[df_annotations["shape_name"] == "Point"]

    # load the image 
    test_image = np.array(Image.open(in_file))
    #test_image = get_image(image_name, input_dir)

    out_files = []
    point_prompts = []
    species = []
    for row in np.arange(0, len(df_annotations), 1):
        #print(f"\nRow: {row}")

        out_files.append(os.path.join(output_dir, dir_path, basename + "_" +str(row) + image_suffix))
        #print(f"\nProcessing {image_name}")
        #print(f"\nOutfiles: {out_files}")
    
        # get point coordinates; df_annotations.loc[row, "x"]; float(y), float(x)
        point_prompt = [float(df_annotations.loc[row, "x"]),float(df_annotations.loc[row, "y"])] #2704 - x
            #df_points.loc[row]["points"].apply(get_point_coord).to_list())
        point_prompts.append(point_prompt)
     #   print(point_prompts)

        # get label names
        species.append(df_points.loc[row]["label_name"])
    
    #print(species)

    #print(point_prompts)
    point_prompts = np.array(point_prompts, dtype=np.float32)
    prompt_labels = np.ones(len(point_prompts))  # positive prompt
    species = np.array(species)
    #print(point_prompts)
    #print(prompt_labels)  
    #print(species)  
        
        # plot image + points
    #    fig, ax = plt.subplots(1, 1, figsize=(10, 10))
    #    ax.imshow(test_image)
    #    show_points(point_prompts, prompt_labels, ax, marker_size=20)
    #    plt.show()

    # get the SAM predictions for each point
    print(f"getting predictions for {len(point_prompts)} point prompts...")
    all_masks = []
    all_scores = []
    all_species = []
    predictor.set_image(test_image)
    for i in range(len(point_prompts)):
        masks, scores, logits = predictor.predict(
            point_coords=point_prompts[i : i + 1],
            point_labels=prompt_labels[i : i + 1],
            multimask_output=False,
        )
        all_masks.append(masks)
        all_scores.append(scores)
        all_species.append(species[i : i + 1])
        
    
    for i in range(len(point_prompts)):
        #print(all_species[i])
        print(i)
        plot_mask_and_label(all_masks[i], all_species[i], out_files[i], input_point=point_prompts[i], input_label=prompt_labels[i], image=test_image, saveit = True)

    all_masks = None
    all_scores = None
    all_species = None
    
        #print(f"getting predictions for {len(point_prompts)} point prompts...")
        #all_masks = []
        #all_scores = []
        #all_species = []
        #predictor.set_image(test_image)
        #for i in range(len(point_prompts)):
        #    masks, scores, logits = predictor.predict(
        #        point_coords=point_prompts[i : i + 1],
        #        point_labels=prompt_labels[i : i + 1],
        #        multimask_output=False,
        #    )
        #    all_masks.append(masks)
        #    all_scores.append(scores)
        #    all_species.append(species[i : i + 1])
            
        # show the results
        #show_res_multi(all_masks, all_scores, image=test_image, input_box=None, saveit = True)
        #show_res(all_masks, all_scores, all_species, input_points=point_prompts, input_labels=prompt_labels, input_box=None, image=test_image, saveit = True)

# %% [markdown]
# Recursively pass through the subfolders - start with input_folder. If you find a file ending with ".jpg" (which is specified in "image_suffix") process the file

# %%
def process_folder_aux():
    process_folder("")

def process_folder(dir_path):
    full_dir = os.path.join(input_dir, dir_path)
    full_out_dir = os.path.join(output_dir, dir_path)
    
    for item in os.listdir(full_dir):
        item_path = os.path.join(full_dir, item)
        out_item_path = os.path.join(full_out_dir, item)
        
        if os.path.isdir(item_path):
            os.makedirs(out_item_path, exist_ok=True)
            process_folder(os.path.join(dir_path, item))
        elif item.endswith(image_suffix):
            process_file(dir_path, item)


# Run the process
process_folder_aux()

# %%
df_points = df_annotations[df_annotations["shape_name"] == "Point"]
df_points

# %%
df_points.groupby("filename").count()

# %%
sam_checkpoint = "../../SAM_models/sam_vit_h_4b8939.pth"
model_type = "vit_h"

sam = sam_model_registry[model_type](checkpoint=sam_checkpoint)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
sam.to(device=device)

predictor = SamPredictor(sam)

# %%
user_id = 2813
first_name = "Nils"
last_name = "Jacobsen"
last_ann_label_id = int(df_annotations["annotation_label_id"].max())
last_label_id = int(df_annotations["label_id"].max())
last_annotation_id = int(df_annotations["annotation_id"].max())
polygon_id = 3

df_new_annotations = df_annotations.copy()
results_dir = Path("../../results/training_data/1")
results_dir.mkdir(exist_ok=True)

print(last_ann_label_id)
print(last_label_id)
print(last_annotation_id)

# %%
for image_name, row_locations in df_points.groupby("filename").groups.items():
    print(f"\nRow locations: {row_locations}")
    print(f"\nProcessing {image_name}")
    if len(row_locations) < 3:
        # the image has only the Laser Points
        print("the image has only the laser points")
        continue

    # load the image
    test_image = get_image(image_name, input_dir)
    
    # get point coordinates
    point_prompts = (
        df_points.loc[row_locations]["points"].apply(get_point_coord).to_list()
    )
    # get label names
    species = (
        df_points.loc[row_locations]["label_name"].to_list()
    )
    point_prompts = np.array(point_prompts, dtype=np.float32)
    prompt_labels = np.ones(len(point_prompts))  # positive prompt

    # plot image + points
    fig, ax = plt.subplots(1, 1, figsize=(9, 8))
    ax.imshow(test_image)
    show_points(point_prompts, prompt_labels, ax, marker_size=15)
    plt.show()

    # get the SAM predictions for each point
    print(f"getting predictions for {len(point_prompts)} point prompts...")
    all_masks = []
    all_scores = []
    all_species = []
    predictor.set_image(test_image)
    for i in range(len(point_prompts)):
        masks, scores, logits = predictor.predict(
            point_coords=point_prompts[i : i + 1],
            point_labels=prompt_labels[i : i + 1],
            multimask_output=False,
        )
        all_masks.append(masks)
        all_scores.append(scores)
        all_species.append(species[i : i + 1])
        
    # show the results
    #show_res_multi(all_masks, all_scores, image=test_image, input_box=None, saveit = True)
    show_res(all_masks, all_scores, all_species, input_points=point_prompts, input_labels=prompt_labels, input_box=None, image=test_image, saveit = True)

    # save all masks
    image_id = int(df_points.loc[row_locations[0], "image_id"])
    print(image_id)
    filename = df_points.loc[row_locations[0], "filename"]
    print(filename)
    image_file = input_dir.joinpath(filename)
    print(image_file)
    
    #save_masks_on_images(all_masks, test_image, image_file.stem, results_dir)
    save_image_masks(all_masks, image_file.stem, results_dir)

    # mask to polygons
    print("getting polygons from masks...")
    for i, masks in enumerate(all_masks):
        mask = masks[0]
        polygon = get_polygon(mask)
        # add an annotation row into the annotation csv table
        last_ann_label_id += 1
        last_label_id += 1
        last_annotation_id += 1
        row_idx = len(df_new_annotations.index)
        df_new_annotations.loc[row_idx, "image_id"] = image_id
        df_new_annotations.loc[row_idx, "filename"] = filename
        df_new_annotations.loc[row_idx, "user_id"] = user_id
        df_new_annotations.loc[row_idx, "firstname"] = first_name
        df_new_annotations.loc[row_idx, "lastname"] = last_name
        df_new_annotations.loc[row_idx, "annotation_label_id"] = last_ann_label_id
        df_new_annotations.loc[row_idx, "label_id"] = last_label_id
        df_new_annotations.loc[row_idx, "annotation_id"] = last_annotation_id
        df_new_annotations.loc[row_idx, "label_hierarchy"] = df_points.loc[
            row_locations[i], "label_hierarchy"
        ]
        df_new_annotations.loc[row_idx, "label_name"] = df_points.loc[
            row_locations[i], "label_name"
        ]
        df_new_annotations.loc[row_idx, "shape_id"] = polygon_id
        df_new_annotations.loc[row_idx, "shape_name"] = "Polygon"
        df_new_annotations.loc[row_idx, "points"] = str(polygon.ravel().tolist())


print("\n\nDone!")

# %%
df_new_annotations

# %%
df_new_annotations.to_csv(results_dir.joinpath("new_annotation.csv"), index=False)
